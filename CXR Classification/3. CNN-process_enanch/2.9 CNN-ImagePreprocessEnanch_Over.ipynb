# %%
# !nvidia-smi
# Out:
# Fri Feb 10 11:58:13 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 528.24       Driver Version: 528.24       CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   55C    P8    N/A /  N/A |   1853MiB /  2048MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A     10328    C+G   ...ser\Application\brave.exe    N/A      |
# |    0   N/A  N/A     10728      C   ...conda3\envs\tf\python.exe    N/A      |
# |    0   N/A  N/A     11792      C   ...conda3\envs\tf\python.exe    N/A      |
# +-----------------------------------------------------------------------------+

# %%
# !nvcc -V
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:41:10_Pacific_Daylight_Time_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 12151677134713004603
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 1297474971
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 6695397469065531639
# physical_device_desc: "device: 0, name: NVIDIA GeForce MX450, pci bus id: 0000:01:00.0, compute capability: 7.5"
# xla_global_id: 416903419
# ]

# %%
# Keras e TF

import tensorflow as tf 
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Conv2D, Conv1D, MaxPooling2D, Dense, Flatten, BatchNormalization, Activation, AveragePooling2D, Input, Flatten, Dropout
from keras.callbacks import ModelCheckpoint

# Sk-Learn
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix, ConfusionMatrixDisplay, roc_curve, roc_auc_score, RocCurveDisplay, accuracy_score, classification_report, confusion_matrix
# Base
import os 
from matplotlib import pyplot as plt
import seaborn as sns # 
import numpy as np #
import pandas as pd # 

import pydot
import pydotplus
from pydotplus import graphviz

# %%
# Set visualization size for figures 
plt.rcParams['figure.figsize'] = [7,7] # width, height

# %% [markdown]
# # Image generator

# %% [markdown]
# In this neural network, pre-processed and enanchment-improved data are used

# %%
batch_size = 32 

train_path = 'C:/Users/marco/Desktop/Local_Documents/data/COVIDx-splitted-resized-112-process-enanch-augm/train'
test_path = 'C:/Users/marco/Desktop/Local_Documents/data/COVIDx-splitted-resized-112-process-enanch-augm/test'

train_datagen = ImageDataGenerator(rescale=1./255., validation_split=0.2)
test_datagen = ImageDataGenerator(rescale=1./255.)

# %%
train_data = train_datagen.flow_from_directory(
        train_path,  
        target_size=(112, 112),  # Lo inserisco per precauzione
        batch_size=batch_size,
        seed=123,
        shuffle=True,
        subset='training',
        class_mode='categorical')
# Out:
# Found 37700 images belonging to 3 classes.

# %%
validation_data = train_datagen.flow_from_directory(
        train_path,  
        target_size=(112, 112),  # Lo inserisco per precauzione
        batch_size=batch_size,
        seed=123,
        shuffle=True,
        subset='validation',
        class_mode='categorical')
# Out:
# Found 9422 images belonging to 3 classes.

# %%
# Test set
test_data = test_datagen.flow_from_directory(
        test_path,  
        target_size=(112, 112),  # Lo inserisco per precauzione
        batch_size=batch_size,
        shuffle=False,
        class_mode='categorical')
# Out:
# Found 397 images belonging to 3 classes.

# %% [markdown]
# # Architecture Definition

# %%
#Definizione del CallBacks: Early stopper sulla loss di validazione
early_stopper = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=100)

# %%
version = "v1"
img_size = '112'
checkpoint_filepath = f'C:/Users/marco/Desktop/Local_Documents/models/Processing_Enanch_Oversampling_Augm/dcnn_model_{img_size}_{version}_val_acc_best.hdf5'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

# %%
num_classes = 3
inputs = keras.Input((112,112,3))

x = inputs

x = keras.layers.Conv2D(16, 3, padding ="same", strides=1)(x)
x = keras.layers.Activation('relu')(x)
x = keras.layers.BatchNormalization()(x)

x = keras.layers.Conv2D(32, 3,  padding ="same", strides=1)(x)
x = keras.layers.Activation('relu')(x)
x = keras.layers.MaxPooling2D(pool_size=(3,3), strides=(3,3))(x)
x = keras.layers.Dropout(0.2)(x)

x = keras.layers.Conv2D(64, 3,  padding ="same", strides=1)(x)
x = keras.layers.Activation('relu')(x)
x = keras.layers.BatchNormalization()(x)

x = keras.layers.Conv2D(128, 2,  padding ="same", strides=1)(x)
x = keras.layers.Activation('relu')(x)

x = keras.layers.MaxPooling2D(pool_size=(2,2), strides=(3,3))(x)

x = keras.layers.Dropout(0.2)(x)

# x = keras.layers.GlobalMaxPool2D()(x)
x = keras.layers.Flatten()(x)

x = keras.layers.Dense(128, activation='relu')(x)
x = keras.layers.Dropout(0.5)(x)

# x = keras.layers.Dense(512, activation='relu')(x)
# x = keras.layers.Dropout(0.5)(x)

# x = keras.layers.Dense(1000, activation='relu')(x)
# x = keras.layers.Dropout(0.5)(x)

outputs = keras.layers.Dense(num_classes, activation='softmax')(x)
net_dcnn_112_process_enanch_over = keras.Model(inputs, outputs)

# %%
net_dcnn_112_process_enanch_over.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 112, 112, 3)]     0
#
#  conv2d_4 (Conv2D)           (None, 112, 112, 16)      448
#
#  activation_4 (Activation)   (None, 112, 112, 16)      0
#
#  batch_normalization_2 (Batc  (None, 112, 112, 16)     64
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 112, 112, 32)      4640
#
#  activation_5 (Activation)   (None, 112, 112, 32)      0
#
#  max_pooling2d_2 (MaxPooling  (None, 37, 37, 32)       0
#  2D)
#
#  dropout_3 (Dropout)         (None, 37, 37, 32)        0
#
#  conv2d_6 (Conv2D)           (None, 37, 37, 64)        18496
#
#  activation_6 (Activation)   (None, 37, 37, 64)        0
#
#  batch_normalization_3 (Batc  (None, 37, 37, 64)       256
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 37, 37, 128)       32896
#
#  activation_7 (Activation)   (None, 37, 37, 128)       0
#
#  max_pooling2d_3 (MaxPooling  (None, 12, 12, 128)      0
#  2D)
#
#  dropout_4 (Dropout)         (None, 12, 12, 128)       0
#
#  flatten_1 (Flatten)         (None, 18432)             0
#
#  dense_2 (Dense)             (None, 128)               2359424
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 2,416,611
# Trainable params: 2,416,451
# Non-trainable params: 160
# _________________________________________________________________

# %% [markdown]
# # Model Fit

# %%
METRICS = [ 
      keras.metrics.CategoricalAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc'),
      keras.metrics.TopKCategoricalAccuracy(name='top 2 accuracy', k=2),
]
OPTIMIZER = keras.optimizers.Adam(learning_rate=0.0001)

# %%
# batch size 
step_per_epoch_train = len(train_data.labels) // batch_size
print(step_per_epoch_train)
step_per_epoch_val = len(validation_data.labels) // batch_size
print(step_per_epoch_val)
# Out:
# 1178
# 294

# %%
net_dcnn_112_process_enanch_over.compile(loss=keras.losses.categorical_crossentropy,
            optimizer = OPTIMIZER,
            metrics=METRICS)

# %%
history_dcnn_over = net_dcnn_112_process_enanch_over.fit(train_data,
          epochs=50,
          steps_per_epoch=step_per_epoch_train,
          validation_data=validation_data,
          validation_steps=step_per_epoch_val,
          workers = 3,
          callbacks=[model_checkpoint_callback, early_stopper])
# Out:
# Epoch 1/50
# 1178/1178 [==============================] - 115s 91ms/step - loss: 0.6400 - accuracy: 0.7212 - precision: 0.7652 - recall: 0.6549 - auc: 0.8872 - top 2 accuracy: 0.9361 - val_loss: 0.4420 - val_accuracy: 0.8340 - val_precision: 0.8709 - val_recall: 0.7890 - val_auc: 0.9532 - val_top 2 accuracy: 0.9691
# Epoch 2/50
# 1178/1178 [==============================] - 106s 90ms/step - loss: 0.4965 - accuracy: 0.7944 - precision: 0.8211 - recall: 0.7587 - auc: 0.9322 - top 2 accuracy: 0.9652 - val_loss: 0.3611 - val_accuracy: 0.8597 - val_precision: 0.8747 - val_recall: 0.8384 - val_auc: 0.9660 - val_top 2 accuracy: 0.9862
# Epoch 3/50
# 1178/1178 [==============================] - 105s 89ms/step - loss: 0.4334 - accuracy: 0.8244 - precision: 0.8446 - recall: 0.7988 - auc: 0.9483 - top 2 accuracy: 0.9748 - val_loss: 0.3144 - val_accuracy: 0.8829 - val_precision: 0.8924 - val_recall: 0.8672 - val_auc: 0.9751 - val_top 2 accuracy: 0.9904
# Epoch 4/50
# 1178/1178 [==============================] - 103s 88ms/step - loss: 0.3725 - accuracy: 0.8529 - precision: 0.8660 - recall: 0.8347 - auc: 0.9615 - top 2 accuracy: 0.9814 - val_loss: 0.3122 - val_accuracy: 0.8824 - val_precision: 0.8899 - val_recall: 0.8735 - val_auc: 0.9727 - val_top 2 accuracy: 0.9863
# Epoch 5/50
# 1178/1178 [==============================] - 109s 92ms/step - loss: 0.3479 - accuracy: 0.8640 - precision: 0.8758 - recall: 0.8496 - auc: 0.9662 - top 2 accuracy: 0.9842 - val_loss: 0.2801 - val_accuracy: 0.8956 - val_precision: 0.9048 - val_recall: 0.8846 - val_auc: 0.9789 - val_top 2 accuracy: 0.9902
# Epoch 6/50
# 1178/1178 [==============================] - 104s 88ms/step - loss: 0.3279 - accuracy: 0.8719 - precision: 0.8813 - recall: 0.8588 - auc: 0.9698 - top 2 accuracy: 0.9871 - val_loss: 0.2618 - val_accuracy: 0.9005 - val_precision: 0.9046 - val_recall: 0.8932 - val_auc: 0.9803 - val_top 2 accuracy: 0.9913
# Epoch 7/50
# 1178/1178 [==============================] - 107s 91ms/step - loss: 0.3095 - accuracy: 0.8793 - precision: 0.8883 - recall: 0.8676 - auc: 0.9729 - top 2 accuracy: 0.9878 - val_loss: 0.2280 - val_accuracy: 0.9122 - val_precision: 0.9142 - val_recall: 0.9099 - val_auc: 0.9847 - val_top 2 accuracy: 0.9952
# Epoch 8/50
# 1178/1178 [==============================] - 110s 94ms/step - loss: 0.2893 - accuracy: 0.8887 - precision: 0.8965 - recall: 0.8792 - auc: 0.9763 - top 2 accuracy: 0.9886 - val_loss: 0.2114 - val_accuracy: 0.9163 - val_precision: 0.9188 - val_recall: 0.9142 - val_auc: 0.9865 - val_top 2 accuracy: 0.9954
# Epoch 9/50
# 1178/1178 [==============================] - 108s 92ms/step - loss: 0.2772 - accuracy: 0.8941 - precision: 0.9013 - recall: 0.8857 - auc: 0.9781 - top 2 accuracy: 0.9906 - val_loss: 0.2608 - val_accuracy: 0.9014 - val_precision: 0.9073 - val_recall: 0.8954 - val_auc: 0.9803 - val_top 2 accuracy: 0.9909
# Epoch 10/50
# 1178/1178 [==============================] - 109s 92ms/step - loss: 0.2637 - accuracy: 0.8998 - precision: 0.9067 - recall: 0.8926 - auc: 0.9800 - top 2 accuracy: 0.9919 - val_loss: 0.1957 - val_accuracy: 0.9249 - val_precision: 0.9277 - val_recall: 0.9221 - val_auc: 0.9885 - val_top 2 accuracy: 0.9959
# Epoch 11/50
# 1178/1178 [==============================] - 109s 92ms/step - loss: 0.2526 - accuracy: 0.9024 - precision: 0.9084 - recall: 0.8949 - auc: 0.9816 - top 2 accuracy: 0.9924 - val_loss: 0.2369 - val_accuracy: 0.9098 - val_precision: 0.9134 - val_recall: 0.9076 - val_auc: 0.9838 - val_top 2 accuracy: 0.9933
# Epoch 12/50
# 1178/1178 [==============================] - 108s 92ms/step - loss: 0.2395 - accuracy: 0.9079 - precision: 0.9130 - recall: 0.9019 - auc: 0.9834 - top 2 accuracy: 0.9928 - val_loss: 0.2529 - val_accuracy: 0.9053 - val_precision: 0.9127 - val_recall: 0.8997 - val_auc: 0.9818 - val_top 2 accuracy: 0.9884
# Epoch 13/50
# 1178/1178 [==============================] - 107s 91ms/step - loss: 0.2350 - accuracy: 0.9089 - precision: 0.9146 - recall: 0.9023 - auc: 0.9839 - top 2 accuracy: 0.9932 - val_loss: 0.2161 - val_accuracy: 0.9170 - val_precision: 0.9183 - val_recall: 0.9145 - val_auc: 0.9859 - val_top 2 accuracy: 0.9952
# Epoch 14/50
# 1178/1178 [==============================] - 108s 92ms/step - loss: 0.2259 - accuracy: 0.9130 - precision: 0.9182 - recall: 0.9079 - auc: 0.9851 - top 2 accuracy: 0.9934 - val_loss: 0.2556 - val_accuracy: 0.9090 - val_precision: 0.9130 - val_recall: 0.9056 - val_auc: 0.9809 - val_top 2 accuracy: 0.9935
# Epoch 15/50
# 1178/1178 [==============================] - 110s 93ms/step - loss: 0.2137 - accuracy: 0.9161 - precision: 0.9204 - recall: 0.9111 - auc: 0.9866 - top 2 accuracy: 0.9947 - val_loss: 0.2548 - val_accuracy: 0.9062 - val_precision: 0.9081 - val_recall: 0.9038 - val_auc: 0.9815 - val_top 2 accuracy: 0.9947
# Epoch 16/50
# 1178/1178 [==============================] - 116s 98ms/step - loss: 0.2106 - accuracy: 0.9190 - precision: 0.9232 - recall: 0.9139 - auc: 0.9869 - top 2 accuracy: 0.9946 - val_loss: 0.3498 - val_accuracy: 0.8699 - val_precision: 0.8727 - val_recall: 0.8675 - val_auc: 0.9679 - val_top 2 accuracy: 0.9911
# Epoch 17/50
# 1178/1178 [==============================] - 112s 95ms/step - loss: 0.2039 - accuracy: 0.9215 - precision: 0.9248 - recall: 0.9171 - auc: 0.9876 - top 2 accuracy: 0.9953 - val_loss: 0.1979 - val_accuracy: 0.9276 - val_precision: 0.9292 - val_recall: 0.9252 - val_auc: 0.9881 - val_top 2 accuracy: 0.9964
# Epoch 18/50
# 1178/1178 [==============================] - 113s 96ms/step - loss: 0.1940 - accuracy: 0.9234 - precision: 0.9273 - recall: 0.9195 - auc: 0.9888 - top 2 accuracy: 0.9956 - val_loss: 0.1998 - val_accuracy: 0.9290 - val_precision: 0.9304 - val_recall: 0.9273 - val_auc: 0.9880 - val_top 2 accuracy: 0.9966
# Epoch 19/50
# 1178/1178 [==============================] - 111s 94ms/step - loss: 0.1909 - accuracy: 0.9263 - precision: 0.9298 - recall: 0.9225 - auc: 0.9891 - top 2 accuracy: 0.9958 - val_loss: 0.1861 - val_accuracy: 0.9326 - val_precision: 0.9343 - val_recall: 0.9315 - val_auc: 0.9891 - val_top 2 accuracy: 0.9965
# Epoch 20/50
# 1178/1178 [==============================] - 110s 93ms/step - loss: 0.1824 - accuracy: 0.9303 - precision: 0.9332 - recall: 0.9269 - auc: 0.9900 - top 2 accuracy: 0.9964 - val_loss: 0.4596 - val_accuracy: 0.8570 - val_precision: 0.8612 - val_recall: 0.8531 - val_auc: 0.9605 - val_top 2 accuracy: 0.9747
# Epoch 21/50
# 1178/1178 [==============================] - 111s 94ms/step - loss: 0.1799 - accuracy: 0.9288 - precision: 0.9324 - recall: 0.9256 - auc: 0.9903 - top 2 accuracy: 0.9961 - val_loss: 0.1857 - val_accuracy: 0.9322 - val_precision: 0.9331 - val_recall: 0.9311 - val_auc: 0.9891 - val_top 2 accuracy: 0.9972
# Epoch 22/50
# 1178/1178 [==============================] - 109s 92ms/step - loss: 0.1724 - accuracy: 0.9329 - precision: 0.9363 - recall: 0.9296 - auc: 0.9911 - top 2 accuracy: 0.9961 - val_loss: 0.2103 - val_accuracy: 0.9269 - val_precision: 0.9276 - val_recall: 0.9264 - val_auc: 0.9865 - val_top 2 accuracy: 0.9963
# Epoch 23/50
# 1178/1178 [==============================] - 107s 91ms/step - loss: 0.1645 - accuracy: 0.9353 - precision: 0.9377 - recall: 0.9321 - auc: 0.9917 - top 2 accuracy: 0.9968 - val_loss: 0.2801 - val_accuracy: 0.9120 - val_precision: 0.9130 - val_recall: 0.9102 - val_auc: 0.9799 - val_top 2 accuracy: 0.9934
# Epoch 24/50
# 1178/1178 [==============================] - 113s 96ms/step - loss: 0.1614 - accuracy: 0.9366 - precision: 0.9396 - recall: 0.9337 - auc: 0.9920 - top 2 accuracy: 0.9974 - val_loss: 0.1872 - val_accuracy: 0.9328 - val_precision: 0.9346 - val_recall: 0.9313 - val_auc: 0.9891 - val_top 2 accuracy: 0.9966
# Epoch 25/50
# 1178/1178 [==============================] - 113s 96ms/step - loss: 0.1593 - accuracy: 0.9366 - precision: 0.9393 - recall: 0.9343 - auc: 0.9922 - top 2 accuracy: 0.9969 - val_loss: 0.1851 - val_accuracy: 0.9363 - val_precision: 0.9370 - val_recall: 0.9357 - val_auc: 0.9895 - val_top 2 accuracy: 0.9965
# Epoch 26/50
# 1178/1178 [==============================] - 107s 91ms/step - loss: 0.1550 - accuracy: 0.9390 - precision: 0.9410 - recall: 0.9364 - auc: 0.9925 - top 2 accuracy: 0.9977 - val_loss: 0.2423 - val_accuracy: 0.9202 - val_precision: 0.9212 - val_recall: 0.9191 - val_auc: 0.9837 - val_top 2 accuracy: 0.9942
# Epoch 27/50
# 1178/1178 [==============================] - 110s 94ms/step - loss: 0.1515 - accuracy: 0.9391 - precision: 0.9418 - recall: 0.9366 - auc: 0.9930 - top 2 accuracy: 0.9974 - val_loss: 0.1780 - val_accuracy: 0.9404 - val_precision: 0.9413 - val_recall: 0.9401 - val_auc: 0.9898 - val_top 2 accuracy: 0.9970
# Epoch 28/50
# 1178/1178 [==============================] - 109s 92ms/step - loss: 0.1448 - accuracy: 0.9432 - precision: 0.9457 - recall: 0.9414 - auc: 0.9935 - top 2 accuracy: 0.9975 - val_loss: 0.2304 - val_accuracy: 0.9235 - val_precision: 0.9240 - val_recall: 0.9227 - val_auc: 0.9850 - val_top 2 accuracy: 0.9954
# Epoch 29/50
# 1178/1178 [==============================] - 109s 92ms/step - loss: 0.1429 - accuracy: 0.9441 - precision: 0.9466 - recall: 0.9417 - auc: 0.9937 - top 2 accuracy: 0.9975 - val_loss: 0.2474 - val_accuracy: 0.9148 - val_precision: 0.9160 - val_recall: 0.9127 - val_auc: 0.9831 - val_top 2 accuracy: 0.9932
# Epoch 30/50
# 1178/1178 [==============================] - 125s 106ms/step - loss: 0.1384 - accuracy: 0.9445 - precision: 0.9466 - recall: 0.9427 - auc: 0.9941 - top 2 accuracy: 0.9976 - val_loss: 0.2289 - val_accuracy: 0.9245 - val_precision: 0.9253 - val_recall: 0.9238 - val_auc: 0.9846 - val_top 2 accuracy: 0.9969
# Epoch 31/50
# 1178/1178 [==============================] - 116s 98ms/step - loss: 0.1329 - accuracy: 0.9470 - precision: 0.9488 - recall: 0.9448 - auc: 0.9945 - top 2 accuracy: 0.9980 - val_loss: 0.1921 - val_accuracy: 0.9315 - val_precision: 0.9325 - val_recall: 0.9309 - val_auc: 0.9887 - val_top 2 accuracy: 0.9974
# Epoch 32/50
# 1178/1178 [==============================] - 118s 100ms/step - loss: 0.1294 - accuracy: 0.9483 - precision: 0.9505 - recall: 0.9465 - auc: 0.9947 - top 2 accuracy: 0.9977 - val_loss: 0.2188 - val_accuracy: 0.9322 - val_precision: 0.9323 - val_recall: 0.9319 - val_auc: 0.9863 - val_top 2 accuracy: 0.9964
# Epoch 33/50
# 1178/1178 [==============================] - 112s 95ms/step - loss: 0.1262 - accuracy: 0.9483 - precision: 0.9501 - recall: 0.9465 - auc: 0.9950 - top 2 accuracy: 0.9980 - val_loss: 0.2084 - val_accuracy: 0.9353 - val_precision: 0.9358 - val_recall: 0.9348 - val_auc: 0.9876 - val_top 2 accuracy: 0.9963
# Epoch 34/50
# 1178/1178 [==============================] - 118s 100ms/step - loss: 0.1267 - accuracy: 0.9489 - precision: 0.9506 - recall: 0.9469 - auc: 0.9950 - top 2 accuracy: 0.9978 - val_loss: 0.2578 - val_accuracy: 0.9289 - val_precision: 0.9292 - val_recall: 0.9288 - val_auc: 0.9834 - val_top 2 accuracy: 0.9963
# Epoch 35/50
# 1178/1178 [==============================] - 111s 94ms/step - loss: 0.1231 - accuracy: 0.9499 - precision: 0.9518 - recall: 0.9483 - auc: 0.9952 - top 2 accuracy: 0.9983 - val_loss: 0.2541 - val_accuracy: 0.9247 - val_precision: 0.9254 - val_recall: 0.9239 - val_auc: 0.9830 - val_top 2 accuracy: 0.9947
# Epoch 36/50
# 1178/1178 [==============================] - 112s 95ms/step - loss: 0.1197 - accuracy: 0.9515 - precision: 0.9528 - recall: 0.9498 - auc: 0.9955 - top 2 accuracy: 0.9984 - val_loss: 0.4242 - val_accuracy: 0.8820 - val_precision: 0.8846 - val_recall: 0.8797 - val_auc: 0.9673 - val_top 2 accuracy: 0.9805
# Epoch 37/50
# 1178/1178 [==============================] - 111s 94ms/step - loss: 0.1141 - accuracy: 0.9538 - precision: 0.9554 - recall: 0.9520 - auc: 0.9960 - top 2 accuracy: 0.9984 - val_loss: 0.2261 - val_accuracy: 0.9288 - val_precision: 0.9292 - val_recall: 0.9284 - val_auc: 0.9856 - val_top 2 accuracy: 0.9959
# Epoch 38/50
# 1178/1178 [==============================] - 111s 94ms/step - loss: 0.1123 - accuracy: 0.9543 - precision: 0.9561 - recall: 0.9526 - auc: 0.9960 - top 2 accuracy: 0.9981 - val_loss: 0.2120 - val_accuracy: 0.9356 - val_precision: 0.9368 - val_recall: 0.9351 - val_auc: 0.9871 - val_top 2 accuracy: 0.9952
# Epoch 39/50
# 1178/1178 [==============================] - 114s 97ms/step - loss: 0.1113 - accuracy: 0.9540 - precision: 0.9557 - recall: 0.9527 - auc: 0.9960 - top 2 accuracy: 0.9984 - val_loss: 0.2368 - val_accuracy: 0.9283 - val_precision: 0.9286 - val_recall: 0.9275 - val_auc: 0.9842 - val_top 2 accuracy: 0.9969
# Epoch 40/50
# 1178/1178 [==============================] - 120s 102ms/step - loss: 0.1084 - accuracy: 0.9565 - precision: 0.9577 - recall: 0.9549 - auc: 0.9962 - top 2 accuracy: 0.9986 - val_loss: 0.2902 - val_accuracy: 0.9169 - val_precision: 0.9186 - val_recall: 0.9167 - val_auc: 0.9805 - val_top 2 accuracy: 0.9943
# Epoch 41/50
# 1178/1178 [==============================] - 113s 96ms/step - loss: 0.1041 - accuracy: 0.9563 - precision: 0.9578 - recall: 0.9551 - auc: 0.9966 - top 2 accuracy: 0.9990 - val_loss: 0.2194 - val_accuracy: 0.9363 - val_precision: 0.9365 - val_recall: 0.9360 - val_auc: 0.9871 - val_top 2 accuracy: 0.9972
# Epoch 42/50
# 1178/1178 [==============================] - 118s 100ms/step - loss: 0.1004 - accuracy: 0.9588 - precision: 0.9601 - recall: 0.9579 - auc: 0.9968 - top 2 accuracy: 0.9987 - val_loss: 0.2551 - val_accuracy: 0.9322 - val_precision: 0.9327 - val_recall: 0.9321 - val_auc: 0.9836 - val_top 2 accuracy: 0.9956
# Epoch 43/50
# 1178/1178 [==============================] - 117s 99ms/step - loss: 0.0979 - accuracy: 0.9607 - precision: 0.9618 - recall: 0.9596 - auc: 0.9969 - top 2 accuracy: 0.9990 - val_loss: 0.6839 - val_accuracy: 0.8720 - val_precision: 0.8734 - val_recall: 0.8712 - val_auc: 0.9512 - val_top 2 accuracy: 0.9748
# Epoch 44/50
# 1178/1178 [==============================] - 117s 99ms/step - loss: 0.0990 - accuracy: 0.9602 - precision: 0.9616 - recall: 0.9589 - auc: 0.9969 - top 2 accuracy: 0.9987 - val_loss: 0.2105 - val_accuracy: 0.9405 - val_precision: 0.9408 - val_recall: 0.9405 - val_auc: 0.9878 - val_top 2 accuracy: 0.9973
# Epoch 45/50
# 1178/1178 [==============================] - 117s 99ms/step - loss: 0.0956 - accuracy: 0.9611 - precision: 0.9625 - recall: 0.9603 - auc: 0.9971 - top 2 accuracy: 0.9988 - val_loss: 0.2199 - val_accuracy: 0.9410 - val_precision: 0.9413 - val_recall: 0.9407 - val_auc: 0.9875 - val_top 2 accuracy: 0.9972
# Epoch 46/50
# 1178/1178 [==============================] - 115s 97ms/step - loss: 0.0935 - accuracy: 0.9619 - precision: 0.9630 - recall: 0.9610 - auc: 0.9972 - top 2 accuracy: 0.9990 - val_loss: 0.2629 - val_accuracy: 0.9274 - val_precision: 0.9283 - val_recall: 0.9267 - val_auc: 0.9833 - val_top 2 accuracy: 0.9945
# Epoch 47/50
# 1178/1178 [==============================] - 119s 101ms/step - loss: 0.0941 - accuracy: 0.9600 - precision: 0.9613 - recall: 0.9588 - auc: 0.9971 - top 2 accuracy: 0.9989 - val_loss: 0.3103 - val_accuracy: 0.9106 - val_precision: 0.9109 - val_recall: 0.9102 - val_auc: 0.9786 - val_top 2 accuracy: 0.9965
# Epoch 48/50
# 1178/1178 [==============================] - 114s 97ms/step - loss: 0.0906 - accuracy: 0.9621 - precision: 0.9631 - recall: 0.9613 - auc: 0.9974 - top 2 accuracy: 0.9989 - val_loss: 0.2674 - val_accuracy: 0.9278 - val_precision: 0.9284 - val_recall: 0.9272 - val_auc: 0.9827 - val_top 2 accuracy: 0.9960
# Epoch 49/50
# 1178/1178 [==============================] - 114s 96ms/step - loss: 0.0899 - accuracy: 0.9631 - precision: 0.9645 - recall: 0.9621 - auc: 0.9973 - top 2 accuracy: 0.9987 - val_loss: 0.2379 - val_accuracy: 0.9398 - val_precision: 0.9401 - val_recall: 0.9394 - val_auc: 0.9853 - val_top 2 accuracy: 0.9971
# Epoch 50/50
# 1178/1178 [==============================] - 119s 101ms/step - loss: 0.0866 - accuracy: 0.9637 - precision: 0.9645 - recall: 0.9628 - auc: 0.9975 - top 2 accuracy: 0.9994 - val_loss: 0.3327 - val_accuracy: 0.9204 - val_precision: 0.9207 - val_recall: 0.9203 - val_auc: 0.9779 - val_top 2 accuracy: 0.9952

# %%
np.save(f'C:/Users/marco/Desktop/Local_Documents/models/Processing_Enanch_Oversampling_Augm/dcnn_history_{img_size}_{version}.npy',
        history_dcnn_over.history)

# %% [markdown]
# Visualization of the learning curves

# %%
# Loss
plt.subplot(1, 2, 1)
plt.plot(history_dcnn_over.history['loss'])
plt.plot(history_dcnn_over.history['val_loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['train', 'validation'])

# Accuracy
plt.subplot(1, 2, 2)
plt.plot(history_dcnn_over.history['accuracy'])
plt.plot(history_dcnn_over.history['val_accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['train', 'validation'])

# %% [markdown]
# # Load Model

# %%
os.chdir('C:/Users/marco/Desktop/Local_Documents/models/Processing_Enanch_Oversampling_Augm')

# %%
# Load model
net_dcnn_112_process_enanch_over = keras.models.load_model("dcnn_model_112_v1_val_acc_best.hdf5")

# %%
# Load hystory and convert to dict
history = np.load('dcnn_history_112_v1.npy', allow_pickle=True).item()

# %% [markdown]
# # Model Evaluation

# %%
# Set visualization size for figures 
plt.rcParams['figure.figsize'] = [5,5] # width, height

# %%
CATEGORIES = "COVID", "NORMAL","PNEUMONIA"

# %%
history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'precision', 'recall', 'auc', 'top 2 accuracy', 'val_loss', 'val_accuracy', 'val_precision', 'val_recall', 'val_auc', 'val_top 2 accuracy'])

# %%
# %matplotlib inline

def print_graph(item, index, history):
    plt.figure()
    train_values = history[item][0:index]
    plt.plot(train_values)
    test_values = history['val_' + item][0:index]
    plt.plot(test_values)
    plt.legend(['training','validation'])
    plt.title('Training and validation '+ item)
    plt.xlabel('epoch')
    plt.show()
    plot = '{}.png'.format(item)
    plt.savefig(plot)

# %%
def test_set_results(pred_value, n=1):    
    y_test = test_data.labels
    X_test, _ = test_data.next()
    
    corr_pred = confusion_matrix(y_test, pred_value)
    fig=plt.figure(figsize=(5, 5))
    ax = plt.axes()
    
    sns.heatmap(corr_pred,annot=True, fmt="d",cmap="Purples", xticklabels=CATEGORIES, yticklabels=CATEGORIES)
    ax.set_title('Confusione Matrix')
    plt.show()
    
    n_correct = int(corr_pred[0][0] + corr_pred[1][1] + corr_pred[2][2])
    print('...'*15)

    print('> Correct Predictions:', n_correct)
    
    n_wrongs = len(y_test) - n_correct
    print('> Wrong Predictions:', n_wrongs)
    print('...'*15)
    
    print(classification_report(test_data.labels, pred_value, target_names=CATEGORIES))

# %%
def printResults(name, model):
    predictions = model.predict(test_data, verbose=1)
    preds = np.argmax(predictions, axis=1)
    test_set_results(preds)

# %%
def model_summary(model, history, name):
    val_acc = history['val_accuracy'] #validation accuracy history
    index= val_acc.index(max(val_acc))
    print('Best Epochs:', index)


    test_loss, test_accuracy, test_precision, test_recall, auc, _, = model.evaluate(test_data, verbose=1)

    train_accuracy = history['accuracy'][index]
    train_loss = history['loss'][index]

    print_graph('loss', index, history)
    print_graph('accuracy', index, history)

    print('---'*15) 
    print(name)
    print('> Accuracy on train:',round(train_accuracy, 2), 
            '\tLoss on train:', round(train_loss,2))
    

    print('> Accuracy on test:',round(test_accuracy, 2),
            '\tLoss on test:',round(test_loss,2))

    print('---'*15)
    print('> predicting test')
    print('---'*15)

    printResults(name, model)

# %%
model_summary(net_dcnn_112_process_enanch_over, history, 'DCCN - Oversampling - Preprocessing - Enanchment')
# Out:
# Best Epochs: 44
# 13/13 [==============================] - 1s 45ms/step - loss: 0.4284 - accuracy: 0.8766 - precision: 0.8785 - recall: 0.8741 - auc: 0.9712 - top 2 accuracy: 0.9849
# ---------------------------------------------
# DCCN - Oversampling - Preprocessing - Enanchment
# > Accuracy on train: 0.96 	Loss on train: 0.1
# > Accuracy on test: 0.88 	Loss on test: 0.43
# ---------------------------------------------
# > predicting test
# ---------------------------------------------
# 13/13 [==============================] - 0s 28ms/step
# .............................................
# > Correct Predictions: 348
# > Wrong Predictions: 49
# .............................................
#               precision    recall  f1-score   support
#
#        COVID       0.97      0.84      0.90       199
#       NORMAL       0.76      0.94      0.84        99
#    PNEUMONIA       0.86      0.88      0.87        99
#
#     accuracy                           0.88       397
#    macro avg       0.86      0.89      0.87       397
# weighted avg       0.89      0.88      0.88       397
