# %% [markdown]
# # Preliminary operation and Import Packages

# %% [markdown]
# 2.9 version of TensorFlow/Keras, because some data augmentation techniques are particularly slow

# %%
# %pip install tensorflow-gpu==2.8.3 
# %pip install -U scikit-learn

# %%
# !nvidia-smi
# Out:
# Mon Feb  6 21:40:24 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 528.24       Driver Version: 528.24       CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   54C    P0    N/A /  N/A |    214MiB /  2048MiB |      2%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      8184    C+G   ...ser\Application\brave.exe    N/A      |
# +-----------------------------------------------------------------------------+

# %%
# !nvcc -V
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:41:10_Pacific_Daylight_Time_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 3053378521526046220
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 1297474971
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 2118325974425920900
# physical_device_desc: "device: 0, name: NVIDIA GeForce MX450, pci bus id: 0000:01:00.0, compute capability: 7.5"
# xla_global_id: 416903419
# ]

# %%
# Keras e TF

import tensorflow as tf 
from tensorflow import keras
from tensorflow.keras.utils import load_img
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, Conv1D, MaxPooling2D, Dense, Flatten, BatchNormalization, Activation, AveragePooling2D, Input, Flatten, Dropout
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras import regularizers
from tensorflow import initializers
from keras.layers import LSTM
# from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence
from keras.layers import TimeDistributed
from keras.layers import LSTM
from keras.models import load_model
from keras.layers import Activation

# Sk-Learn
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix

# Image management
import cv2

from time import time
import sys
import os
import glob2 as glob
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from scipy.linalg import fractional_matrix_power

from sklearn.utils import resample
from sklearn.utils import shuffle
from sklearn.utils import class_weight 

import pydot
import pydotplus
from pydotplus import graphviz

# %%
# Set the directory where the label  is stored

# path = 'C:/Users/marco/Desktop/Local_Documents/data'
# os.chdir(path=path)

# %%
# Set visualization size for figures 
plt.rcParams['figure.figsize'] = [10,10] # width, height

# %% [markdown]
# ## *Original images generator[OLD]

# %%
target_size = (224,224) # Target size
batch_size = 64 # Batch size

train_path = 'C:/Users/marco/Desktop/Local_Documents/data/train/'
test_path = 'C:/Users/marco/Desktop/Local_Documents/data/test/'   

train_datagen = ImageDataGenerator(rescale=1./255.)
test_datagen = ImageDataGenerator(rescale=1./255.)

# %%
os.chdir(train_path)

#Training set
train_data = train_datagen.flow_from_dataframe(
dataframe=train_label_under,
directory=train_path,
x_col="img_path",
y_col="label",
batch_size=batch_size,
seed=123,
shuffle=True,
class_mode="categorical",
target_size=target_size)

# %%
os.chdir(train_path)

# Validation set
validation_data = test_datagen.flow_from_dataframe(
dataframe=val_label_under,
directory=train_path,
x_col="img_path",
y_col="label",
batch_size=batch_size,
seed=123,
shuffle=True,
class_mode="categorical",
target_size=target_size)
# Out:
# Found 1650 validated image filenames belonging to 3 classes.
# c:\Users\marco\Documents\venv\DL\lib\site-packages\keras_preprocessing\image\dataframe_iterator.py:283: UserWarning: Found 17 invalid image filename(s) in x_col="img_path". These filename(s) will be ignored.
#   warnings.warn(

# %%
os.chdir(test_path)

# Test set
test_data = test_datagen.flow_from_dataframe(
dataframe=test_label,
directory=test_path,
x_col="img_path",
y_col=None,
batch_size=batch_size,
seed=123,
shuffle=False,
class_mode=None,
target_size=target_size)
# Out:
# Found 400 validated image filenames.

# %%
class_names = train_data.class_indices
print(class_names)
# Out:
# {'COVID-19': 0, 'normal': 1, 'pneumonia': 2}

# %% [markdown]
# # Models

# %%
#Definizione del CallBacks: Early stopper sulla loss di validazione
early_stopper = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=100)

# %%
version = "v2"
arc = "a1"
checkpoint_filepath = f'C:/Users/marco/Desktop/Local_Documents/models/cnn_model__fs_{version}_{arc}_val_acc_best.hdf5'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

# %% [markdown]
# ## 1. CNN from scratch

# %% [markdown]
# -  Downsample dataset
# - No image processing
# - No data Augmentation
# - 30 epochs

# %%
num_classes = 3

# %%
# Architecture definition
inputs = keras.Input((224,224,3))

x = inputs
x = keras.layers.Conv2D(32, 3, padding='same')(x)
x = keras.layers.Activation('relu')(x)
x = keras.layers.MaxPooling2D(3, strides=3, padding='same')(x)

x = keras.layers.Conv2D(64, 3, padding='same')(x)
x = keras.layers.Activation('relu')(x)

x = keras.layers.GlobalMaxPooling2D()(x)

outputs = keras.layers.Dense(num_classes, activation='softmax')(x)
net_cnn_1 = keras.Model(inputs, outputs)

# %%
net_cnn_1.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d_2 (Conv2D)           (None, 224, 224, 32)      896
#
#  activation_2 (Activation)   (None, 224, 224, 32)      0
#
#  max_pooling2d_1 (MaxPooling  (None, 75, 75, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 75, 75, 64)        18496
#
#  activation_3 (Activation)   (None, 75, 75, 64)        0
#
#  global_max_pooling2d_1 (Glo  (None, 64)               0
#  balMaxPooling2D)
#
#  dense_1 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 19,587
# Trainable params: 19,587
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(net, to_file=f'C:/Users/marco/Desktop/Local_Documents/model/plot/{version}/cnn_schema_fs_{version}_{arc}.png', show_shapes=True, show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
# Compile the model for training
net_cnn_1.compile(loss=keras.losses.categorical_crossentropy,
            optimizer = keras.optimizers.Adam(learning_rate=0.001),
            metrics=['accuracy'])

# %%
history_cnn_1 = net_cnn_1.fit_generator(train_data,
          epochs=100,
          validation_data=validation_data,
          workers = 1,
          callbacks=[model_checkpoint_callback, early_stopper])
# Out:
# C:\Users\marco\AppData\Local\Temp\ipykernel_10784\4285332846.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history_cnn_1 = net_cnn_1.fit_generator(train_data,
# Epoch 1/100
# 233/233 [==============================] - 333s 1s/step - loss: 0.7790 - accuracy: 0.6741 - val_loss: 0.6462 - val_accuracy: 0.7170
# Epoch 2/100
# 233/233 [==============================] - 372s 2s/step - loss: 0.6023 - accuracy: 0.7547 - val_loss: 0.5813 - val_accuracy: 0.7570
# Epoch 3/100
# 233/233 [==============================] - 355s 2s/step - loss: 0.5538 - accuracy: 0.7715 - val_loss: 0.5648 - val_accuracy: 0.7558
# Epoch 4/100
# 233/233 [==============================] - 345s 1s/step - loss: 0.5268 - accuracy: 0.7833 - val_loss: 0.5523 - val_accuracy: 0.7745
# Epoch 83/100
# 233/233 [==============================] - 363s 2s/step - loss: 0.1639 - accuracy: 0.9409 - val_loss: 0.5538 - val_accuracy: 0.8255
# Epoch 84/100
# 233/233 [==============================] - 362s 2s/step - loss: 0.1640 - accuracy: 0.9372 - val_loss: 0.5516 - val_accuracy: 0.8182
# Epoch 85/100
# 233/233 [==============================] - 362s 2s/step - loss: 0.1621 - accuracy: 0.9404 - val_loss: 0.6109 - val_accuracy: 0.8218
# Epoch 86/100
# 233/233 [==============================] - 358s 2s/step - loss: 0.1722 - accuracy: 0.9329 - val_loss: 0.5672 - val_accuracy: 0.8315
# Epoch 87/100
# 233/233 [==============================] - 357s 2s/step - loss: 0.1551 - accuracy: 0.9432 - val_loss: 0.5519 - val_accuracy: 0.8230
# Epoch 88/100
# 233/233 [==============================] - 369s 2s/step - loss: 0.1564 - accuracy: 0.9426 - val_loss: 0.5734 - val_accuracy: 0.8224
# Epoch 89/100
# 233/233 [==============================] - 361s 2s/step - loss: 0.1605 - accuracy: 0.9395 - val_loss: 0.5877 - val_accuracy: 0.8182
# Epoch 90/100
# 233/233 [==============================] - 366s 2s/step - loss: 0.1558 - accuracy: 0.9433 - val_loss: 0.5708 - val_accuracy: 0.8200
# Epoch 91/100
# 233/233 [==============================] - 360s 2s/step - loss: 0.1467 - accuracy: 0.9468 - val_loss: 0.6304 - val_accuracy: 0.8085
# Epoch 92/100
# 233/233 [==============================] - 357s 2s/step - loss: 0.1598 - accuracy: 0.9366 - val_loss: 0.6301 - val_accuracy: 0.8236
# Epoch 93/100
# 233/233 [==============================] - 363s 2s/step - loss: 0.1466 - accuracy: 0.9478 - val_loss: 0.5861 - val_accuracy: 0.8212
# Epoch 94/100
# 233/233 [==============================] - 343s 1s/step - loss: 0.1532 - accuracy: 0.9448 - val_loss: 0.5766 - val_accuracy: 0.8188
# Epoch 95/100
# 233/233 [==============================] - 924s 4s/step - loss: 0.1461 - accuracy: 0.9453 - val_loss: 0.6244 - val_accuracy: 0.8224
# Epoch 96/100
# 233/233 [==============================] - 391s 2s/step - loss: 0.1524 - accuracy: 0.9429 - val_loss: 0.6349 - val_accuracy: 0.8194
# Epoch 97/100
# 233/233 [==============================] - 1098s 5s/step - loss: 0.1371 - accuracy: 0.9498 - val_loss: 0.6097 - val_accuracy: 0.8194
# Epoch 98/100
# 233/233 [==============================] - 335s 1s/step - loss: 0.1407 - accuracy: 0.9488 - val_loss: 0.6048 - val_accuracy: 0.8236
# Epoch 99/100
# 233/233 [==============================] - 342s 1s/step - loss: 0.1449 - accuracy: 0.9459 - val_loss: 0.6058 - val_accuracy: 0.8267
# Epoch 100/100
# 233/233 [==============================] - 348s 1s/step - loss: 0.1276 - accuracy: 0.9551 - val_loss: 0.5988 - val_accuracy: 0.8230

# %%
np.save(f'C:/Users/marco/Desktop/Local_Documents/models/cnn_1_fs_{version}_{arc}.npy',
        history_cnn_1.history)

# %%
# Visualization of the learning curves

# Loss
plt.subplot(1, 2, 1)
plt.plot(history_cnn_1.history['loss'])
plt.plot(history_cnn_1.history['val_loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['train', 'test'])

# Accuracy
plt.subplot(1, 2, 2)
plt.plot(history_cnn_1.history['accuracy'])
plt.plot(history_cnn_1.history['val_accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['train', 'test'])

# %% [markdown]
# ## 2. CNN from scratch w\AGC

# %% [markdown]
# -  Downsample dataset
# - Adaptive Gamma Correction
# - No data Augmentation
# - 30 epochs

# %%
num_classes = 3

# %%
# Architecture definition
inputs = keras.Input((224,224,3))

x = inputs
x = keras.layers.Conv2D(32, 3, padding='same')(x)
x = keras.layers.Activation('relu')(x)
x = keras.layers.MaxPooling2D(3, strides=3, padding='same')(x)

x = keras.layers.Conv2D(64, 3, padding='same')(x)
x = keras.layers.Activation('relu')(x)
x = keras.layers.GlobalMaxPooling2D()(x)

outputs = keras.layers.Dense(num_classes, activation='softmax')(x)
net_cnn_gc = keras.Model(inputs, outputs)

# %%
net_cnn_gc.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d_2 (Conv2D)           (None, 224, 224, 32)      896
#
#  activation_2 (Activation)   (None, 224, 224, 32)      0
#
#  max_pooling2d_1 (MaxPooling  (None, 75, 75, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 75, 75, 64)        18496
#
#  activation_3 (Activation)   (None, 75, 75, 64)        0
#
#  global_max_pooling2d_1 (Glo  (None, 64)               0
#  balMaxPooling2D)
#
#  dense (Dense)               (None, 3)                 195
#
# =================================================================
# Total params: 19,587
# Trainable params: 19,587
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model for training
net_cnn_gc.compile(loss=keras.losses.categorical_crossentropy,
            optimizer = keras.optimizers.Adam(learning_rate=0.0001),
            metrics=['accuracy'])

# %%
history_cnn_agc = net_cnn_gc.fit_generator(train_gc,
          epochs=100,
          validation_data=validation_data_gc,
          workers = 1,
          callbacks=[model_checkpoint_callback, early_stopper])
# Out:
# C:\Users\marco\AppData\Local\Temp\ipykernel_36888\3744893962.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history_cnn_agc = net_cnn_gc.fit_generator(train_gc,
# Epoch 1/100
# 166/166 [==============================] - 158s 949ms/step - loss: 0.8984 - accuracy: 0.5704 - val_loss: 0.8392 - val_accuracy: 0.6414
# Epoch 2/100
# 166/166 [==============================] - 158s 949ms/step - loss: 0.8085 - accuracy: 0.6494 - val_loss: 0.7974 - val_accuracy: 0.6597
# Epoch 3/100
# 166/166 [==============================] - 158s 949ms/step - loss: 0.7785 - accuracy: 0.6609 - val_loss: 0.7732 - val_accuracy: 0.6681
# Epoch 4/100
# 166/166 [==============================] - 158s 949ms/step - loss: 0.7593 - accuracy: 0.6699 - val_loss: 0.7544 - val_accuracy: 0.6772
# Epoch 5/100
# 166/166 [==============================] - 157s 946ms/step - loss: 0.7429 - accuracy: 0.6772 - val_loss: 0.7412 - val_accuracy: 0.6930
# Epoch 6/100
# 166/166 [==============================] - 159s 957ms/step - loss: 0.7301 - accuracy: 0.6874 - val_loss: 0.7263 - val_accuracy: 0.6947
# Epoch 7/100
# 166/166 [==============================] - 158s 952ms/step - loss: 0.7158 - accuracy: 0.6952 - val_loss: 0.7162 - val_accuracy: 0.7105
# Epoch 8/100
# Epoch 47/100
# 166/166 [==============================] - 171s 1s/step - loss: 0.5608 - accuracy: 0.7665 - val_loss: 0.5997 - val_accuracy: 0.7621
# Epoch 48/100
# 166/166 [==============================] - 162s 978ms/step - loss: 0.5604 - accuracy: 0.7664 - val_loss: 0.5979 - val_accuracy: 0.7596
# Epoch 49/100
# 166/166 [==============================] - 171s 1s/step - loss: 0.5592 - accuracy: 0.7639 - val_loss: 0.5920 - val_accuracy: 0.7587
# Epoch 50/100
# 166/166 [==============================] - 166s 997ms/step - loss: 0.5568 - accuracy: 0.7682 - val_loss: 0.6017 - val_accuracy: 0.7579
# Epoch 51/100
# 166/166 [==============================] - 167s 1s/step - loss: 0.5562 - accuracy: 0.7667 - val_loss: 0.5904 - val_accuracy: 0.7596
# Epoch 52/100
# 166/166 [==============================] - 170s 1s/step - loss: 0.5528 - accuracy: 0.7680 - val_loss: 0.5888 - val_accuracy: 0.7637
# Epoch 53/100
# 166/166 [==============================] - 167s 1s/step - loss: 0.5524 - accuracy: 0.7692 - val_loss: 0.5897 - val_accuracy: 0.7654
# Epoch 54/100
# 166/166 [==============================] - 168s 1s/step - loss: 0.5504 - accuracy: 0.7708 - val_loss: 0.5919 - val_accuracy: 0.7612
# Epoch 55/100
# 166/166 [==============================] - 162s 978ms/step - loss: 0.5488 - accuracy: 0.7696 - val_loss: 0.5974 - val_accuracy: 0.7579
# Epoch 56/100
# 166/166 [==============================] - 172s 1s/step - loss: 0.5497 - accuracy: 0.7690 - val_loss: 0.6023 - val_accuracy: 0.7479
# Epoch 57/100
# 166/166 [==============================] - 171s 1s/step - loss: 0.5459 - accuracy: 0.7710 - val_loss: 0.5878 - val_accuracy: 0.7662
# Epoch 58/100
# 166/166 [==============================] - 172s 1s/step - loss: 0.5443 - accuracy: 0.7705 - val_loss: 0.5929 - val_accuracy: 0.7546
# Epoch 59/100
# 166/166 [==============================] - 180s 1s/step - loss: 0.5430 - accuracy: 0.7710 - val_loss: 0.5838 - val_accuracy: 0.7604
# Epoch 60/100
# 166/166 [==============================] - 168s 1s/step - loss: 0.5429 - accuracy: 0.7702 - val_loss: 0.5867 - val_accuracy: 0.7654
# Epoch 61/100
# 166/166 [==============================] - 168s 1s/step - loss: 0.5400 - accuracy: 0.7742 - val_loss: 0.5837 - val_accuracy: 0.7662
# Epoch 62/100
# 166/166 [==============================] - 164s 988ms/step - loss: 0.5393 - accuracy: 0.7734 - val_loss: 0.5827 - val_accuracy: 0.7679
# Epoch 63/100
# 166/166 [==============================] - 173s 1s/step - loss: 0.5382 - accuracy: 0.7756 - val_loss: 0.5805 - val_accuracy: 0.7621
# Epoch 64/100
# 166/166 [==============================] - 162s 977ms/step - loss: 0.5353 - accuracy: 0.7756 - val_loss: 0.5831 - val_accuracy: 0.7687
# Epoch 65/100
# 166/166 [==============================] - 171s 1s/step - loss: 0.5349 - accuracy: 0.7745 - val_loss: 0.5782 - val_accuracy: 0.7629
# Epoch 66/100
# 166/166 [==============================] - 168s 1s/step - loss: 0.5359 - accuracy: 0.7754 - val_loss: 0.5792 - val_accuracy: 0.7696
# Epoch 67/100
# 166/166 [==============================] - 185s 1s/step - loss: 0.5316 - accuracy: 0.7780 - val_loss: 0.5778 - val_accuracy: 0.7696
# Epoch 68/100
# 166/166 [==============================] - 180s 1s/step - loss: 0.5322 - accuracy: 0.7765 - val_loss: 0.5797 - val_accuracy: 0.7720
# Epoch 69/100
# 166/166 [==============================] - 171s 1s/step - loss: 0.5298 - accuracy: 0.7780 - val_loss: 0.5828 - val_accuracy: 0.7671
# Epoch 70/100
# 166/166 [==============================] - 176s 1s/step - loss: 0.5282 - accuracy: 0.7782 - val_loss: 0.5760 - val_accuracy: 0.7671
# Epoch 71/100
# 166/166 [==============================] - 162s 975ms/step - loss: 0.5268 - accuracy: 0.7781 - val_loss: 0.5858 - val_accuracy: 0.7646
# Epoch 72/100
# 166/166 [==============================] - 170s 1s/step - loss: 0.5266 - accuracy: 0.7779 - val_loss: 0.5736 - val_accuracy: 0.7654
# Epoch 73/100
# 166/166 [==============================] - 171s 1s/step - loss: 0.5232 - accuracy: 0.7810 - val_loss: 0.5738 - val_accuracy: 0.7612
# Epoch 74/100
# 166/166 [==============================] - 166s 999ms/step - loss: 0.5240 - accuracy: 0.7806 - val_loss: 0.5744 - val_accuracy: 0.7646
# Epoch 75/100
# 166/166 [==============================] - 166s 1s/step - loss: 0.5222 - accuracy: 0.7800 - val_loss: 0.5991 - val_accuracy: 0.7446
# Epoch 76/100
# 166/166 [==============================] - 162s 975ms/step - loss: 0.5208 - accuracy: 0.7823 - val_loss: 0.5745 - val_accuracy: 0.7729
# Epoch 77/100
# 166/166 [==============================] - 169s 1s/step - loss: 0.5190 - accuracy: 0.7823 - val_loss: 0.5799 - val_accuracy: 0.7662
# Epoch 78/100
# 166/166 [==============================] - 166s 1s/step - loss: 0.5198 - accuracy: 0.7824 - val_loss: 0.5698 - val_accuracy: 0.7712
# Epoch 79/100
# 166/166 [==============================] - 171s 1s/step - loss: 0.5182 - accuracy: 0.7831 - val_loss: 0.5729 - val_accuracy: 0.7696
# Epoch 80/100
# 166/166 [==============================] - 173s 1s/step - loss: 0.5171 - accuracy: 0.7831 - val_loss: 0.5844 - val_accuracy: 0.7662
# Epoch 81/100
# 166/166 [==============================] - 160s 965ms/step - loss: 0.5140 - accuracy: 0.7837 - val_loss: 0.5726 - val_accuracy: 0.7712
# Epoch 82/100
# 166/166 [==============================] - 168s 1s/step - loss: 0.5128 - accuracy: 0.7876 - val_loss: 0.5683 - val_accuracy: 0.7729
# Epoch 83/100
# 166/166 [==============================] - 171s 1s/step - loss: 0.5118 - accuracy: 0.7861 - val_loss: 0.5679 - val_accuracy: 0.7662
# Epoch 84/100
# 166/166 [==============================] - 163s 982ms/step - loss: 0.5116 - accuracy: 0.7867 - val_loss: 0.5686 - val_accuracy: 0.7662
# Epoch 85/100
# 166/166 [==============================] - 175s 1s/step - loss: 0.5099 - accuracy: 0.7864 - val_loss: 0.5701 - val_accuracy: 0.7704
# Epoch 86/100
# 166/166 [==============================] - 183s 1s/step - loss: 0.5093 - accuracy: 0.7848 - val_loss: 0.5670 - val_accuracy: 0.7696
# Epoch 87/100
# 166/166 [==============================] - 167s 1s/step - loss: 0.5086 - accuracy: 0.7877 - val_loss: 0.5782 - val_accuracy: 0.7729
# Epoch 88/100
# 166/166 [==============================] - 171s 1s/step - loss: 0.5078 - accuracy: 0.7894 - val_loss: 0.5704 - val_accuracy: 0.7729
# Epoch 89/100
# 166/166 [==============================] - 170s 1s/step - loss: 0.5067 - accuracy: 0.7864 - val_loss: 0.5707 - val_accuracy: 0.7679
# Epoch 90/100
# 166/166 [==============================] - 172s 1s/step - loss: 0.5087 - accuracy: 0.7860 - val_loss: 0.5730 - val_accuracy: 0.7720
# Epoch 91/100
# 166/166 [==============================] - 176s 1s/step - loss: 0.5039 - accuracy: 0.7903 - val_loss: 0.5631 - val_accuracy: 0.7662
# Epoch 92/100
# 166/166 [==============================] - 166s 1s/step - loss: 0.5024 - accuracy: 0.7907 - val_loss: 0.5632 - val_accuracy: 0.7729
# Epoch 93/100
# 166/166 [==============================] - 174s 1s/step - loss: 0.5009 - accuracy: 0.7911 - val_loss: 0.5691 - val_accuracy: 0.7646
# Epoch 94/100
# 166/166 [==============================] - 160s 963ms/step - loss: 0.5001 - accuracy: 0.7925 - val_loss: 0.5640 - val_accuracy: 0.7604
# Epoch 95/100
# 166/166 [==============================] - 167s 1s/step - loss: 0.4996 - accuracy: 0.7906 - val_loss: 0.5647 - val_accuracy: 0.7662
# Epoch 96/100
# 166/166 [==============================] - 169s 1s/step - loss: 0.4992 - accuracy: 0.7914 - val_loss: 0.5607 - val_accuracy: 0.7704
# Epoch 97/100
# 166/166 [==============================] - 162s 973ms/step - loss: 0.4958 - accuracy: 0.7937 - val_loss: 0.5603 - val_accuracy: 0.7745
# Epoch 98/100
# 166/166 [==============================] - 169s 1s/step - loss: 0.4965 - accuracy: 0.7926 - val_loss: 0.5600 - val_accuracy: 0.7704
# Epoch 99/100
# 166/166 [==============================] - 161s 966ms/step - loss: 0.4965 - accuracy: 0.7947 - val_loss: 0.5746 - val_accuracy: 0.7679
# Epoch 100/100
# 166/166 [==============================] - 165s 995ms/step - loss: 0.4939 - accuracy: 0.7964 - val_loss: 0.5615 - val_accuracy: 0.7712

# %%
np.save(f'C:/Users/marco/Desktop/Local_Documents/models/cnn_gc_fs_{version}_{arc}.npy',
        history_cnn_1.history)

# %%
# Visualization of the learning curves

# Loss
plt.subplot(1, 2, 1)
plt.plot(history_cnn_agc.history['loss'])
plt.plot(history_cnn_agc.history['val_loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['train', 'test'])

# Accuracy
plt.subplot(1, 2, 2)
plt.plot(history_cnn_agc.history['accuracy'])
plt.plot(history_cnn_agc.history['val_accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['train', 'test'])

# %% [markdown]
# L'applicazione dell'algoritmo Adaptive Gamma correction ha portato ad un miglioramento dei risultato, in termini di contenimento dell'overfitting. Si procede quindi considerando questo tipo di soluzione.
